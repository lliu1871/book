# %% [markdown]
# # Lab 2: Supervised Learning
#
#
# ## Linear Regression

# %%
b = c(0.35,2.7)
x = rnorm(50)
error = rnorm(50,mean=0,sd=1)
y = b[1]+b[2]*x + error

data = data.frame(cbind(y,x))

plot(data$x,data$y,col="blue")

result = lm(data$y~data$x)
result

abline(result$coef,col="red")
# Out:
# Call:
# lm(formula = data$y ~ data$x)
#
# Coefficients:
# (Intercept)       data$x
#      0.1815       2.8582
# plot without title

# %% [markdown]
# ## Multivariate linear regression

# %%
x = matrix(rnorm(30),nrow=10,ncol=3)
b = c(0.5,2.1,-0.9,1.4)
error = rnorm(30,mean=0,sd=1)
y = b[1]+b[2]*x[,1]+b[3]*x[,2]+b[4]*x[,3]+error

data = data.frame(y,x)
data
pairs(data)

result = lm(data$y ~ data$X1 + data$X2 + data$X3)
result
# Out:
#    y           X1         X2          X3
# 1  -0.35903827 -0.4165293  1.45132055  0.271585234
# 2  11.64210044  2.3011223 -0.96977763  2.397653599
# 3   0.87491758 -0.4776926 -0.04636407  1.210279345
# 4  -0.64929321  0.1270577  0.52018320  0.002235074
# 5  -0.92667881 -0.1956624  1.46601490  0.280087024
# 6  -2.17631932 -1.3913041  0.57745271  0.422288174
# 7  -0.07486702 -0.2528659  0.44588404  0.446460076
# 8   1.44792381 -1.0773672 -2.47808017  1.489880257
# 9   3.63544228  1.1075816 -0.97515998  0.001765269
# 10  1.20284767 -0.3365053 -2.99029434 -0.695815704
# 11 -1.72155894 -0.4165293  1.45132055  0.271585234
# 12  9.48368547  2.3011223 -0.96977763  2.397653599
# 13  0.16047684 -0.4776926 -0.04636407  1.210279345
# 14  0.88927622  0.1270577  0.52018320  0.002235074
# 15  0.09434870 -0.1956624  1.46601490  0.280087024
# 16 -2.13080771 -1.3913041  0.57745271  0.422288174
# 17 -0.28666730 -0.2528659  0.44588404  0.446460076
# 18  0.92682585 -1.0773672 -2.47808017  1.489880257
# 19  3.13221684  1.1075816 -0.97515998  0.001765269
# 20  2.47755308 -0.3365053 -2.99029434 -0.695815704
# 21 -1.37921474 -0.4165293  1.45132055  0.271585234
# 22  9.76299978  2.3011223 -0.96977763  2.397653599
# 23  0.77201353 -0.4776926 -0.04636407  1.210279345
# 24 -0.44899949  0.1270577  0.52018320  0.002235074
# 25 -0.18905198 -0.1956624  1.46601490  0.280087024
# 26 -1.72028606 -1.3913041  0.57745271  0.422288174
# 27 -0.85886419 -0.2528659  0.44588404  0.446460076
# 28  1.89083129 -1.0773672 -2.47808017  1.489880257
# 29  4.19350798  1.1075816 -0.97515998  0.001765269
# 30  1.78047955 -0.3365053 -2.99029434 -0.695815704
# Call:
# lm(formula = data$y ~ data$X1 + data$X2 + data$X3)
#
# Coefficients:
# (Intercept)      data$X1      data$X2      data$X3
#      0.5762       2.4100      -0.8055       1.2209
# plot without title

# %% [markdown]
# ## Classification by logistic model

# %%
x = rnorm(100)
b = c(0.5, 0.9)
error = rnorm(100,mean=0,sd=1)
y = b[1]+b[2]*x+error
p = exp(y)/(1+exp(y))
group1 = which(p>0.5)
group2 = which(p<=0.5)
y[group1] = 1
y[group2] = 0

result = glm(y~x, family="binomial")

y_hat = result$coef[1]+result$coef[1]*x
p_hat = exp(y_hat)/(1+exp(y_hat))

print("estimated group1")
which(p_hat>0.5)

print("true group1")
group1
# Out:
# [1] "estimated group1"
#  [1]   2   3   4   5   8   9  10  11  13  14  15  16  17  18  19  20  22  23  24
# [20]  25  26  27  28  29  31  32  33  34  35  36  39  40  41  42  43  44  45  46
# [39]  47  48  49  50  51  53  54  55  56  57  59  61  62  63  64  65  66  67  68
# [58]  69  70  71  72  73  74  75  76  77  78  79  81  82  83  84  85  86  87  89
# [77]  90  94  95  97  98  99 100
# [1] "true group1"
#  [1]  2  3  4  5  8  9 11 13 17 18 19 22 23 24 27 29 33 36 37 38 42 43 44 46 48
# [26] 49 50 51 53 54 55 56 57 59 61 63 64 65 66 67 69 71 72 73 74 75 78 79 80 82
# [51] 83 84 85 86 87 88 89 90 94 95
